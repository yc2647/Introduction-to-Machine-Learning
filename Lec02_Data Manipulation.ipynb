# %%
#import relevant libraries
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('lecture2data.csv')

# %%
#check the column in your dataframe
df.column
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-417348e0a539> in <module>
#       1 #check the column in your dataframe
# ----> 2 df.column
#
# C:\Anaconda\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'column'

# %%
df['Name']
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
df.head(2) #df.tail() to see last few rows
# Out:
#    PassengerId  Survived  Class  \
# 0            1         0      3
# 1            2         1      1
#
#                                                 Name     Sex   Age     Ticket  \
# 0                            Braund, Mr. Owen Harris    male  22.0  A/5 21171
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0   PC 17599
#
#    Fare Cabin Port
# 0  7.25   NaN    S
# 1   NaN   C85    C

# %%
#Filtering 
#Access a group of rows and columns by label(s) or a boolean array.
FareAbove20_YoungerThan20=df.loc[(df['Fare'>20]) | (df['Age']<10)]

FaveAbove20_OderTan40=df.loc[(df['Fare']>20) & (df['Age']>40)]
FareAbove20_OlderThan40.head(10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-31-68e71bd5f9f9> in <module>
#       1 #Filtering
#       2 #Access a group of rows and columns by label(s) or a boolean array.
# ----> 3 FareAbove20_YoungerThan20=df.loc[(df['Fare'>20]) | (df['Age']<10)]
#       4
#       5 FaveAbove20_OderTan40=df.loc[(df['Fare']>20) & (df['Age']>40)]
#
# TypeError: '>' not supported between instances of 'str' and 'int'

# %%
df['Fare'].median()
# Out:
# 14.4

# %%
df.head(9)
# Out:
#    PassengerId  Survived  Class  \
# 0            1         0      3
# 1            2         1      1
# 2            3         1      3
# 3            4         1      1
# 4            5         0      3
# 5            6         0      3
# 6            7         0      1
# 7            8         0      3
# 8            9         1      3
#
#                                                 Name     Sex   Age  \
# 0                            Braund, Mr. Owen Harris    male  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                             Heikkinen, Miss. Laina  female  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                           Allen, Mr. William Henry    male  35.0
# 5                                   Moran, Mr. James    male   NaN
# 6                            McCarthy, Mr. Timothy J    male  54.0
# 7                     Palsson, Master. Gosta Leonard    male   2.0
# ...

# %%
#fill in the info of no-value: fillna

df['Cabin']=df['Cabin'].fillna('Top Deck')
df.head(9)
# Out:
#    PassengerId  Survived  Class  \
# 0            1         0      3
# 1            2         1      1
# 2            3         1      3
# 3            4         1      1
# 4            5         0      3
# 5            6         0      3
# 6            7         0      1
# 7            8         0      3
# 8            9         1      3
#
#                                                 Name     Sex   Age  \
# 0                            Braund, Mr. Owen Harris    male  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                             Heikkinen, Miss. Laina  female  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                           Allen, Mr. William Henry    male  35.0
# 5                                   Moran, Mr. James    male   NaN
# 6                            McCarthy, Mr. Timothy J    male  54.0
# 7                     Palsson, Master. Gosta Leonard    male   2.0
# ...

# %%
#Dummy encoding, adding column for new adding data
df['male']=0
df['female']=0
df
# Out:
#      PassengerId  Survived  Class  \
# 0              1         0      3
# 1              2         1      1
# 2              3         1      3
# 3              4         1      1
# 4              5         0      3
# ..           ...       ...    ...
# 886          887         0      2
# 887          888         1      1
# 888          889         0      3
# 889          890         1      1
# 890          891         0      3
#
#                                                   Name     Sex   Age  \
# 0                              Braund, Mr. Owen Harris    male  22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                               Heikkinen, Miss. Laina  female  26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                             Allen, Mr. William Henry    male  35.0
# ..                                                 ...     ...   ...
# ...

# %%
for x in range(0,len(df)):
    if df['Sex'][x]=='male':
        df['male'][x]=1
    else:
        df['female'][x]=1
df
# Out:
# C:\Anaconda\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Anaconda\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
#      PassengerId  Survived  Class  \
# 0              1         0      3
# 1              2         1      1
# 2              3         1      3
# 3              4         1      1
# 4              5         0      3
# ..           ...       ...    ...
# 886          887         0      2
# ...
